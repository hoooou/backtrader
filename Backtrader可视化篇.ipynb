# %%
import backtrader as bt
import pandas as pd
import numpy as np
import datetime
from copy import deepcopy

# %% [markdown]
# # 一、数据准备

# %% [markdown]
# ## 1.1 读取日度行情表
#
# 表内字段就是 Backtrader 默认情况下要求输入的 7 个字段： 'datetime' 、'open'、'high'、'low'、'close'、'volume'、'openinterest'，外加一个 'sec_code' 股票代码字段。

# %%
daily_price = pd.read_csv("./data/daily_price.csv", parse_dates=['datetime'])
daily_price
# Out:
#          datetime   sec_code        open        high         low       close  \
# 0      2019-01-02  600466.SH   33.064891   33.496709   31.954503   32.386321
# 1      2019-01-02  603228.SH   50.660230   51.458513   50.394136   51.120778
# 2      2019-01-02  600315.SH  148.258423  150.480132  148.258423  149.558935
# 3      2019-01-02  000750.SZ   49.512579   53.154883   48.715825   51.561375
# 4      2019-01-02  002588.SZ   36.608672   36.608672   35.669988   35.763857
# ...           ...        ...         ...         ...         ...         ...
# 255967 2021-01-28  600717.SH  121.489201  122.011736  120.705400  120.966667
# 255968 2021-01-28  300558.SZ  134.155888  137.600704  130.700970  131.569750
# 255969 2021-01-28  600171.SH   39.774873   39.830040   38.864630   38.947380
# 255970 2021-01-28  600597.SH   47.190201   49.243025   46.250355   46.423484
# 255971 2021-01-28  600584.SH  204.725839  210.226650  199.225028  199.799026
#
#            volume  openinterest
# 0        10629352             0
# 1          426147             0
# 2         2138556             0
# 3       227557612             0
# 4         2841517             0
# ...           ...           ...
# 255967    6022213             0
# 255968    5330301             0
# 255969   12354183             0
# 255970   32409940             0
# 255971   68831481             0
#
# [255972 rows x 8 columns]

# %%
# 提取 600315.SH 上海家化
data1 = daily_price.query(f"sec_code=='600315.SH'").set_index('datetime').drop(columns=['sec_code'])
data1
# Out:
#                   open        high         low       close    volume  \
# datetime
# 2019-01-02  148.258423  150.480132  148.258423  149.558935   2138556
# 2019-01-03  149.504747  150.209191  142.514493  143.598253   3032080
# 2019-01-04  140.997228  146.524406  140.076032  146.307654   2957692
# 2019-01-07  147.120474  147.337226  142.839621  143.652441   5665587
# 2019-01-08  143.435689  143.923381  140.997228  142.622869   2009482
# ...                ...         ...         ...         ...       ...
# 2021-01-22  206.677537  208.876234  201.455631  203.159621   5404602
# 2021-01-25  201.895370  207.227211  198.487390  204.423872   5416695
# 2021-01-26  203.929165  208.216625  198.762227  199.421836   4215020
# 2021-01-27  199.806608  204.258970  196.013855  203.764263   4172168
# 2021-01-28  203.324524  223.607505  202.829817  218.770371  18522953
#
#             openinterest
# datetime
# 2019-01-02             0
# 2019-01-03             0
# 2019-01-04             0
# 2019-01-07             0
# 2019-01-08             0
# ...                  ...
# 2021-01-22             0
# 2021-01-25             0
# 2021-01-26             0
# 2021-01-27             0
# 2021-01-28             0
#
# [506 rows x 6 columns]

# %% [markdown]
# # 二、简单均线策略-可视化

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import matplotlib
plt.rcParams['figure.figsize'] = 15, 15

# %%
import backtrader as bt

class TestStrategy(bt.Strategy):
    params = (
        ('period1', 5),
        ('period2', 20),
    )

    def __init__(self):
        sma1 = bt.indicators.SMA(period=self.p.period1)  # 短期均线
        sma2 = bt.indicators.SMA(period=self.p.period2)  # 长期均线
        # 短期均线上穿长期均线，取值为 1；短期均线下穿长期均线，取值为 -1；相等，取值为 0
        self.crossover = bt.indicators.CrossOver(sma1, sma2)  
        self.order = None
        
    def next(self):
        # 下穿卖出
        if self.position:
            if self.crossover < 0.0: 
                self.order = self.close()
                print('CLOSE {} close {}'.format(self.position.size, self.data.close[0]))
        # 上穿买入
        else:
            if self.crossover > 0.0:
                self.order = self.buy(size=100)
                print('BUY {} close {}'.format(100, self.data.close[0]))

        
cerebro = bt.Cerebro()
cerebro.broker.set_cash(100000)
st_date = datetime.datetime(2019,1,2)
ed_date = datetime.datetime(2021,1,28)
datafeed1 = bt.feeds.PandasData(dataname=data1, fromdate=st_date, todate=ed_date)
cerebro.adddata(datafeed1, name='600315.SH')
cerebro.addstrategy(TestStrategy)
cerebro.addobserver(bt.observers.DrawDown)
cerebro.addobserver(bt.observers.TimeReturn)
cerebro.addobserver(bt.observers.Benchmark, data=datafeed1)
# cerebro.addobserver(bt.observers.Broker)
# cerebro.addobserver(bt.observers.Trades)
# cerebro.addobserver(bt.observers.BuySell)
# cerebro.addobserver(bt.observers.TimeReturn)
rasult = cerebro.run()
cerebro.plot(iplot=False)
# Out:
# BUY 100 close 171.01739112
# CLOSE 100 close 167.87448596
# BUY 100 close 154.59842106
# CLOSE 100 close 166.51978546
# BUY 100 close 173.21505054
# CLOSE 100 close 180.31626674
# BUY 100 close 188.34610352
# CLOSE 100 close 181.57263576
# BUY 100 close 167.58870232
# CLOSE 100 close 163.92884474
# BUY 100 close 169.00894556
# CLOSE 100 close 161.03373352
# BUY 100 close 138.03671798
# CLOSE 100 close 255.86228216
# BUY 100 close 254.33278944
# CLOSE 100 close 236.36124998
# BUY 100 close 236.359949
# CLOSE 100 close 213.32859583
# BUY 100 close 228.99431338
# CLOSE 100 close 224.2671144
# BUY 100 close 235.70033984
# CLOSE 100 close 219.48494799
# BUY 100 close 214.09813985
# CLOSE 100 close 208.60139685
# BUY 100 close 219.26507827
# CLOSE 100 close 206.51263451
# BUY 100 close 205.24838362
# CLOSE 100 close 192.60587472
# BUY 100 close 203.15962128
# [[<Figure size 1500x1500 with 8 Axes>]]

# %% [markdown]
# # 三、如何读取 observers 中的数据

# %%
import backtrader as bt

class TestStrategy(bt.Strategy):
    params = (
        ('period1', 5),
        ('period2', 20),
    )

    def __init__(self):
        sma1 = bt.indicators.SMA(period=self.p.period1)  # 短期均线
        sma2 = bt.indicators.SMA(period=self.p.period2)  # 长期均线
        # 短期均线上穿长期均线，取值为 1；短期均线下穿长期均线，取值为 -1；相等，取值为 0
        self.crossover = bt.indicators.CrossOver(sma1, sma2)  
        self.order = None
        
    def next(self):
        print(bt.num2date(self.data.datetime[0]).isoformat())
        print('getcash 当前可用资金', self.broker.getcash())
        print('getvalue 当前总资产', self.broker.getvalue())
        print(bt.num2date(self.data.datetime[-1]).isoformat())
        print('self.stats 当前可用资金', self.stats.broker.cash[0])
        print('self.stats 当前总资产', self.stats.broker.value[0])
        print('self.stats 最大回撤', self.stats.drawdown.drawdown[0])
        print('self.stats 收益', self.stats.timereturn.line[0])
        # 下穿卖出
        if self.position:
            if self.crossover < 0.0: 
                self.order = self.close()
                print(bt.num2date(self.data.datetime[0]).isoformat())
                print('CLOSE {} close {}'.format(self.position.size, self.data.close[0]))
        # 上穿买入
        else:
            if self.crossover > 0.0:
                self.order = self.buy(size=100)
                print(bt.num2date(self.data.datetime[0]).isoformat())
                print('BUY {} close {}'.format(100, self.data.close[0]))
                
    def stop(self):
        print('---------stop----------')
        print(bt.num2date(self.data.datetime[0]).isoformat())
        print('getcash 当前可用资金', self.broker.getcash())
        print('getvalue 当前总资产', self.broker.getvalue())
        print(bt.num2date(self.data.datetime[-1]).isoformat())
        print('self.stats 当前可用资金', self.stats.broker.cash[0])
        print('self.stats 当前总资产', self.stats.broker.value[0])
        print('self.stats 最大回撤', self.stats.drawdown.drawdown[0])
        print('self.stats 收益', self.stats.timereturn.line[0])

        
cerebro = bt.Cerebro()
cerebro.broker.set_cash(100000)
st_date = datetime.datetime(2019,1,2)
ed_date = datetime.datetime(2021,1,28)
datafeed1 = bt.feeds.PandasData(dataname=data1, fromdate=st_date, todate=ed_date)
cerebro.adddata(datafeed1, name='600315.SH')
cerebro.addanalyzer(bt.analyzers.TimeDrawDown, _name='_TimeDrawDown')
cerebro.addanalyzer(bt.analyzers.TimeReturn, _name='_TimeReturn')
cerebro.addstrategy(TestStrategy)
cerebro.addobserver(bt.observers.DrawDown)
cerebro.addobserver(bt.observers.TimeReturn)
cerebro.addobserver(bt.observers.Benchmark, data=datafeed1)
rasult = cerebro.run()
cerebro.plot(iplot=False)
# Out:
# 2019-01-30T00:00:00
# getcash 当前可用资金 100000.0
# getvalue 当前总资产 100000.0
# 2019-01-29T00:00:00
# self.stats 当前可用资金 100000.0
# self.stats 当前总资产 100000.0
# self.stats 最大回撤 0.0
# self.stats 收益 0.0
# 2019-01-31T00:00:00
# getcash 当前可用资金 100000.0
# getvalue 当前总资产 100000.0
# 2019-01-30T00:00:00
# self.stats 当前可用资金 100000.0
# self.stats 当前总资产 100000.0
# self.stats 最大回撤 0.0
# self.stats 收益 0.0
# 2019-02-01T00:00:00
# getcash 当前可用资金 100000.0
# getvalue 当前总资产 100000.0
# 2019-01-31T00:00:00
# self.stats 当前可用资金 100000.0
# self.stats 当前总资产 100000.0
# self.stats 最大回撤 0.0
# self.stats 收益 0.0
# 2019-02-11T00:00:00
# getcash 当前可用资金 100000.0
# getvalue 当前总资产 100000.0
# 2019-02-01T00:00:00
# self.stats 当前可用资金 100000.0
# self.stats 当前总资产 100000.0
# self.stats 最大回撤 0.0
# self.stats 收益 0.0
# 2019-02-12T00:00:00
# getcash 当前可用资金 100000.0
# getvalue 当前总资产 100000.0
# 2019-02-11T00:00:00
# self.stats 当前可用资金 100000.0
# self.stats 当前总资产 100000.0
# self.stats 最大回撤 0.0
# self.stats 收益 0.0
# 2019-02-13T00:00:00
# getcash 当前可用资金 100000.0
# getvalue 当前总资产 100000.0
# 2019-02-12T00:00:00
# self.stats 当前可用资金 100000.0
# self.stats 当前总资产 100000.0
# self.stats 最大回撤 0.0
# self.stats 收益 0.0
# 2019-02-14T00:00:00
# getcash 当前可用资金 100000.0
# getvalue 当前总资产 100000.0
# 2019-02-13T00:00:00
# self.stats 当前可用资金 100000.0
# self.stats 当前总资产 100000.0
# self.stats 最大回撤 0.0
# self.stats 收益 0.0
# 2019-02-15T00:00:00
# getcash 当前可用资金 100000.0
# getvalue 当前总资产 100000.0
# 2019-02-14T00:00:00
# self.stats 当前可用资金 100000.0
# self.stats 当前总资产 100000.0
# self.stats 最大回撤 0.0
# self.stats 收益 0.0
# 2019-02-18T00:00:00
# getcash 当前可用资金 100000.0
# getvalue 当前总资产 100000.0
# 2019-02-15T00:00:00
# self.stats 当前可用资金 100000.0
# self.stats 当前总资产 100000.0
# self.stats 最大回撤 0.0
# self.stats 收益 0.0
# 2019-02-19T00:00:00
# getcash 当前可用资金 100000.0
# getvalue 当前总资产 100000.0
# 2019-02-18T00:00:00
# self.stats 当前可用资金 100000.0
# self.stats 当前总资产 100000.0
# self.stats 最大回撤 0.0
# self.stats 收益 0.0
# 2019-02-20T00:00:00
# getcash 当前可用资金 100000.0
# getvalue 当前总资产 100000.0
# 2019-02-19T00:00:00
# self.stats 当前可用资金 100000.0
# self.stats 当前总资产 100000.0
# self.stats 最大回撤 0.0
# self.stats 收益 0.0
# 2019-02-21T00:00:00
# getcash 当前可用资金 100000.0
# getvalue 当前总资产 100000.0
# 2019-02-20T00:00:00
# self.stats 当前可用资金 100000.0
# self.stats 当前总资产 100000.0
# self.stats 最大回撤 0.0
# self.stats 收益 0.0
# 2019-02-22T00:00:00
# getcash 当前可用资金 100000.0
# getvalue 当前总资产 100000.0
# 2019-02-21T00:00:00
# self.stats 当前可用资金 100000.0
# self.stats 当前总资产 100000.0
# self.stats 最大回撤 0.0
# self.stats 收益 0.0
# 2019-02-25T00:00:00
# getcash 当前可用资金 100000.0
# getvalue 当前总资产 100000.0
# 2019-02-22T00:00:00
# self.stats 当前可用资金 100000.0
# self.stats 当前总资产 100000.0
# self.stats 最大回撤 0.0
# self.stats 收益 0.0
# 2019-02-26T00:00:00
# getcash 当前可用资金 100000.0
# getvalue 当前总资产 100000.0
# 2019-02-25T00:00:00
# self.stats 当前可用资金 100000.0
# self.stats 当前总资产 100000.0
# self.stats 最大回撤 0.0
# self.stats 收益 0.0
# 2019-02-27T00:00:00
# getcash 当前可用资金 100000.0
# getvalue 当前总资产 100000.0
# 2019-02-26T00:00:00
# self.stats 当前可用资金 100000.0
# self.stats 当前总资产 100000.0
# self.stats 最大回撤 0.0
# self.stats 收益 0.0
# 2019-02-28T00:00:00
# getcash 当前可用资金 100000.0
# getvalue 当前总资产 100000.0
# 2019-02-27T00:00:00
# self.stats 当前可用资金 100000.0
# self.stats 当前总资产 100000.0
# self.stats 最大回撤 0.0
# self.stats 收益 0.0
# 2019-03-01T00:00:00
# getcash 当前可用资金 100000.0
# getvalue 当前总资产 100000.0
# 2019-02-28T00:00:00
# self.stats 当前可用资金 100000.0
# self.stats 当前总资产 100000.0
# self.stats 最大回撤 0.0
# self.stats 收益 0.0
# 2019-03-04T00:00:00
# getcash 当前可用资金 100000.0
# getvalue 当前总资产 100000.0
# 2019-03-01T00:00:00
# self.stats 当前可用资金 100000.0
# self.stats 当前总资产 100000.0
# self.stats 最大回撤 0.0
# self.stats 收益 0.0
# 2019-03-05T00:00:00
# getcash 当前可用资金 100000.0
# getvalue 当前总资产 100000.0
# 2019-03-04T00:00:00
# self.stats 当前可用资金 100000.0
# self.stats 当前总资产 100000.0
# self.stats 最大回撤 0.0
# self.stats 收益 0.0
# 2019-03-06T00:00:00
# getcash 当前可用资金 100000.0
# getvalue 当前总资产 100000.0
# 2019-03-05T00:00:00
# self.stats 当前可用资金 100000.0
# self.stats 当前总资产 100000.0
# self.stats 最大回撤 0.0
# self.stats 收益 0.0
# 2019-03-07T00:00:00
# getcash 当前可用资金 100000.0
# getvalue 当前总资产 100000.0
# 2019-03-06T00:00:00
# self.stats 当前可用资金 100000.0
# self.stats 当前总资产 100000.0
# self.stats 最大回撤 0.0
# self.stats 收益 0.0
# 2019-03-08T00:00:00
# getcash 当前可用资金 100000.0
# getvalue 当前总资产 100000.0
# 2019-03-07T00:00:00
# self.stats 当前可用资金 100000.0
# self.stats 当前总资产 100000.0
# self.stats 最大回撤 0.0
# self.stats 收益 0.0
# 2019-03-11T00:00:00
# getcash 当前可用资金 100000.0
# getvalue 当前总资产 100000.0
# 2019-03-08T00:00:00
# self.stats 当前可用资金 100000.0
# self.stats 当前总资产 100000.0
# self.stats 最大回撤 0.0
# self.stats 收益 0.0
# 2019-03-12T00:00:00
# getcash 当前可用资金 100000.0
# getvalue 当前总资产 100000.0
# 2019-03-11T00:00:00
# self.stats 当前可用资金 100000.0
# self.stats 当前总资产 100000.0
# self.stats 最大回撤 0.0
# self.stats 收益 0.0
# 2019-03-13T00:00:00
# getcash 当前可用资金 100000.0
# getvalue 当前总资产 100000.0
# 2019-03-12T00:00:00
# self.stats 当前可用资金 100000.0
# self.stats 当前总资产 100000.0
# self.stats 最大回撤 0.0
# self.stats 收益 0.0
# 2019-03-14T00:00:00
# getcash 当前可用资金 100000.0
# getvalue 当前总资产 100000.0
# 2019-03-13T00:00:00
# self.stats 当前可用资金 100000.0
# self.stats 当前总资产 100000.0
# self.stats 最大回撤 0.0
# self.stats 收益 0.0
# 2019-03-15T00:00:00
# getcash 当前可用资金 100000.0
# getvalue 当前总资产 100000.0
# 2019-03-14T00:00:00
# self.stats 当前可用资金 100000.0
# self.stats 当前总资产 100000.0
# self.stats 最大回撤 0.0
# self.stats 收益 0.0
# 2019-03-18T00:00:00
# getcash 当前可用资金 100000.0
# getvalue 当前总资产 100000.0
# 2019-03-15T00:00:00
# self.stats 当前可用资金 100000.0
# self.stats 当前总资产 100000.0
# self.stats 最大回撤 0.0
# self.stats 收益 0.0
# 2019-03-19T00:00:00
# getcash 当前可用资金 100000.0
# getvalue 当前总资产 100000.0
# 2019-03-18T00:00:00
# self.stats 当前可用资金 100000.0
# self.stats 当前总资产 100000.0
# self.stats 最大回撤 0.0
# self.stats 收益 0.0
# 2019-03-20T00:00:00
# getcash 当前可用资金 100000.0
# getvalue 当前总资产 100000.0
# 2019-03-19T00:00:00
# self.stats 当前可用资金 100000.0
# self.stats 当前总资产 100000.0
# self.stats 最大回撤 0.0
# self.stats 收益 0.0
# 2019-03-21T00:00:00
# getcash 当前可用资金 100000.0
# getvalue 当前总资产 100000.0
# 2019-03-20T00:00:00
# self.stats 当前可用资金 100000.0
# self.stats 当前总资产 100000.0
# self.stats 最大回撤 0.0
# self.stats 收益 0.0
# 2019-03-22T00:00:00
# getcash 当前可用资金 100000.0
# getvalue 当前总资产 100000.0
# 2019-03-21T00:00:00
# self.stats 当前可用资金 100000.0
# self.stats 当前总资产 100000.0
# self.stats 最大回撤 0.0
# self.stats 收益 0.0
# 2019-03-25T00:00:00
# getcash 当前可用资金 100000.0
# getvalue 当前总资产 100000.0
# 2019-03-22T00:00:00
# self.stats 当前可用资金 100000.0
# self.stats 当前总资产 100000.0
# self.stats 最大回撤 0.0
# self.stats 收益 0.0
# 2019-03-26T00:00:00
# getcash 当前可用资金 100000.0
# getvalue 当前总资产 100000.0
# 2019-03-25T00:00:00
# self.stats 当前可用资金 100000.0
# self.stats 当前总资产 100000.0
# self.stats 最大回撤 0.0
# self.stats 收益 0.0
# 2019-03-27T00:00:00
# getcash 当前可用资金 100000.0
# getvalue 当前总资产 100000.0
# 2019-03-26T00:00:00
# self.stats 当前可用资金 100000.0
# self.stats 当前总资产 100000.0
# self.stats 最大回撤 0.0
# self.stats 收益 0.0
# 2019-03-28T00:00:00
# getcash 当前可用资金 100000.0
# getvalue 当前总资产 100000.0
# 2019-03-27T00:00:00
# self.stats 当前可用资金 100000.0
# self.stats 当前总资产 100000.0
# self.stats 最大回撤 0.0
# self.stats 收益 0.0
# 2019-03-29T00:00:00
# getcash 当前可用资金 100000.0
# getvalue 当前总资产 100000.0
# 2019-03-28T00:00:00
# self.stats 当前可用资金 100000.0
# self.stats 当前总资产 100000.0
# self.stats 最大回撤 0.0
# self.stats 收益 0.0
# 2019-04-01T00:00:00
# getcash 当前可用资金 100000.0
# getvalue 当前总资产 100000.0
# 2019-03-29T00:00:00
# self.stats 当前可用资金 100000.0
# self.stats 当前总资产 100000.0
# self.stats 最大回撤 0.0
# self.stats 收益 0.0
# 2019-04-02T00:00:00
# getcash 当前可用资金 100000.0
# getvalue 当前总资产 100000.0
# 2019-04-01T00:00:00
# self.stats 当前可用资金 100000.0
# self.stats 当前总资产 100000.0
# self.stats 最大回撤 0.0
# self.stats 收益 0.0
# 2019-04-03T00:00:00
# getcash 当前可用资金 100000.0
# getvalue 当前总资产 100000.0
# 2019-04-02T00:00:00
# self.stats 当前可用资金 100000.0
# self.stats 当前总资产 100000.0
# self.stats 最大回撤 0.0
# self.stats 收益 0.0
# 2019-04-04T00:00:00
# getcash 当前可用资金 100000.0
# getvalue 当前总资产 100000.0
# 2019-04-03T00:00:00
# self.stats 当前可用资金 100000.0
# self.stats 当前总资产 100000.0
# self.stats 最大回撤 0.0
# self.stats 收益 0.0
# 2019-04-04T00:00:00
# BUY 100 close 171.01739112
# 2019-04-08T00:00:00
# getcash 当前可用资金 82865.748076
# getvalue 当前总资产 99653.196672
# 2019-04-04T00:00:00
# self.stats 当前可用资金 100000.0
# self.stats 当前总资产 100000.0
# self.stats 最大回撤 0.0
# self.stats 收益 0.0
# 2019-04-08T00:00:00
# CLOSE 100 close 167.87448596
# 2019-04-09T00:00:00
# getcash 当前可用资金 99599.008652
# getvalue 当前总资产 99599.008652
# 2019-04-08T00:00:00
# self.stats 当前可用资金 82865.748076
# self.stats 当前总资产 99653.196672
# self.stats 最大回撤 0.3468033279999945
# self.stats 收益 -0.0034680332799998936
# 2019-04-10T00:00:00
# getcash 当前可用资金 99599.008652
# getvalue 当前总资产 99599.008652
# 2019-04-09T00:00:00
# self.stats 当前可用资金 99599.008652
# self.stats 当前总资产 99599.008652
# self.stats 最大回撤 0.4009913479999959
# self.stats 收益 -0.0005437659985796373
# 2019-04-11T00:00:00
# getcash 当前可用资金 99599.008652
# getvalue 当前总资产 99599.008652
# 2019-04-10T00:00:00
# self.stats 当前可用资金 99599.008652
# self.stats 当前总资产 99599.008652
# self.stats 最大回撤 0.4009913479999959
# self.stats 收益 0.0
# 2019-04-12T00:00:00
# getcash 当前可用资金 99599.008652
# getvalue 当前总资产 99599.008652
# 2019-04-11T00:00:00
# self.stats 当前可用资金 99599.008652
# self.stats 当前总资产 99599.008652
# self.stats 最大回撤 0.4009913479999959
# self.stats 收益 0.0
# 2019-04-15T00:00:00
# getcash 当前可用资金 99599.008652
# getvalue 当前总资产 99599.008652
# 2019-04-12T00:00:00
# self.stats 当前可用资金 99599.008652
# self.stats 当前总资产 99599.008652
# self.stats 最大回撤 0.4009913479999959
# self.stats 收益 0.0
# 2019-04-16T00:00:00
# getcash 当前可用资金 99599.008652
# getvalue 当前总资产 99599.008652
# 2019-04-15T00:00:00
# self.stats 当前可用资金 99599.008652
# self.stats 当前总资产 99599.008652
# self.stats 最大回撤 0.4009913479999959
# self.stats 收益 0.0
# 2019-04-17T00:00:00
# getcash 当前可用资金 99599.008652
# getvalue 当前总资产 99599.008652
# 2019-04-16T00:00:00
# self.stats 当前可用资金 99599.008652
# self.stats 当前总资产 99599.008652
# self.stats 最大回撤 0.4009913479999959
# self.stats 收益 0.0
# 2019-04-18T00:00:00
# getcash 当前可用资金 99599.008652
# getvalue 当前总资产 99599.008652
# 2019-04-17T00:00:00
# self.stats 当前可用资金 99599.008652
# self.stats 当前总资产 99599.008652
# self.stats 最大回撤 0.4009913479999959
# self.stats 收益 0.0
# 2019-04-19T00:00:00
# getcash 当前可用资金 99599.008652
# getvalue 当前总资产 99599.008652
# 2019-04-18T00:00:00
# self.stats 当前可用资金 99599.008652
# self.stats 当前总资产 99599.008652
# self.stats 最大回撤 0.4009913479999959
# self.stats 收益 0.0
# 2019-04-22T00:00:00
# getcash 当前可用资金 99599.008652
# getvalue 当前总资产 99599.008652
# 2019-04-19T00:00:00
# self.stats 当前可用资金 99599.008652
# self.stats 当前总资产 99599.008652
# self.stats 最大回撤 0.4009913479999959
# self.stats 收益 0.0
# 2019-04-23T00:00:00
# getcash 当前可用资金 99599.008652
# getvalue 当前总资产 99599.008652
# 2019-04
# self.stats 收益 0.0002715836775810665
# 2019-12-26T00:00:00
# getcash 当前可用资金 84223.330434
# getvalue 当前总资产 100616.214908
# 2019-12-25T00:00:00
# self.stats 当前可用资金 84223.330434
# self.stats 当前总资产 100583.440064
# self.stats 最大回撤 2.4269359732899827
# self.stats 收益 -0.00010860397596534899
# 2019-12-26T00:00:00
# CLOSE 100 close 163.92884474
# ...
# self.stats 最大回撤 6.837205404656115
# self.stats 收益 -0.0009821631515364304
# 2020-10-27T00:00:00
# CLOSE 100 close 224.2671144
# 2020-10-28T00:00:00
# getcash 当前可用资金 107719.973854
# getvalue 当前总资产 107719.973854
# 2020-10-27T00:00:00
# self.stats 当前可用资金 85188.824297
# self.stats 当前总资产 107615.535737
# self.stats 最大回撤 5.622419227787846
# self.stats 收益 0.013039391767333042
# 2020-10-29T00:00:00
# getcash 当前可用资金 107719.973854
# getvalue 当前总资产 107719.973854
# 2020-10-28T00:00:00
# self.stats 当前可用资金 107719.973854
# self.stats 当前总资产 107719.973854
# self.stats 最大回撤 5.530828206516033
# self.stats 收益 0.0009704743491241175
# 2020-10-29T00:00:00
# BUY 100 close 235.70033984
# 2020-10-30T00:00:00
# getcash 当前可用资金 84078.482211
# getvalue 当前总资产 106736.05685699999
# 2020-10-29T00:00:00
# self.stats 当前可用资金 107719.973854
# self.stats 当前总资产 107719.973854
# self.stats 最大回撤 5.530828206516033
# self.stats 收益 0.0
# 2020-11-02T00:00:00
# getcash 当前可用资金 84078.482211
# getvalue 当前总资产 107741.960826
# 2020-10-30T00:00:00
# self.stats 当前可用资金 84078.482211
# self.stats 当前总资产 106736.05685699999
# self.stats 最大回撤 6.393712038497868
# self.stats 收益 -0.00913402558316223
# 2020-11-03T00:00:00
# getcash 当前可用资金 84078.482211
# getvalue 当前总资产 107714.477111
# 2020-11-02T00:00:00
# self.stats 当前可用资金 84078.482211
# self.stats 当前总资产 107741.960826
# self.stats 最大回撤 5.511545886248284
# self.stats 收益 0.009424218943629104
# 2020-11-04T00:00:00
# getcash 当前可用资金 84078.482211
# getvalue 当前总资产 107873.88265799999
# 2020-11-03T00:00:00
# self.stats 当前可用资金 84078.482211
# self.stats 当前总资产 107714.477111
# self.stats 最大回撤 5.535648786582967
# self.stats 收益 -0.00025508831275478094
# 2020-11-05T00:00:00
# getcash 当前可用资金 84078.482211
# getvalue 当前总资产 107824.411971
# 2020-11-04T00:00:00
# self.stats 当前可用资金 84078.482211
# self.stats 当前总资产 107873.88265799999
# self.stats 最大回撤 5.395851964641788
# self.stats 收益 0.0014798897165486657
# 2020-11-06T00:00:00
# getcash 当前可用资金 84078.482211
# getvalue 当前总资产 107791.43151299999
# 2020-11-05T00:00:00
# self.stats 当前可用资金 84078.482211
# self.stats 当前总资产 107824.411971
# self.stats 最大回撤 5.43923718524422
# self.stats 收益 -0.0004585974452855357
# 2020-11-09T00:00:00
# getcash 当前可用资金 84078.482211
# getvalue 当前总资产 107274.737671
# 2020-11-06T00:00:00
# self.stats 当前可用资金 84078.482211
# self.stats 当前总资产 107791.43151299999
# self.stats 最大回撤 5.4681606656458515
# self.stats 收益 -0.00030587190226338823
# 2020-11-10T00:00:00
# getcash 当前可用资金 84078.482211
# getvalue 当前总资产 107230.763727
# 2020-11-09T00:00:00
# self.stats 当前可用资金 84078.482211
# self.stats 当前总资产 107274.737671
# self.stats 最大回撤 5.921295191937978
# self.stats 收益 -0.004793459319980209
# 2020-11-11T00:00:00
# getcash 当前可用资金 84078.482211
# getvalue 当前总资产 106499.696908
# 2020-11-10T00:00:00
# self.stats 当前可用资金 84078.482211
# self.stats 当前总资产 107230.763727
# self.stats 最大回撤 5.959859832473477
# self.stats 收益 -0.0004099189143194071
# 2020-11-12T00:00:00
# getcash 当前可用资金 84078.482211
# getvalue 当前总资产 106565.657824
# 2020-11-11T00:00:00
# self.stats 当前可用资金 84078.482211
# self.stats 当前总资产 106499.696908
# self.stats 最大回撤 6.600996981376175
# self.stats 收益 -0.006817696653371175
# 2020-11-13T00:00:00
# getcash 当前可用资金 84078.482211
# getvalue 当前总资产 106026.97701
# 2020-11-12T00:00:00
# self.stats 当前可用资金 84078.482211
# self.stats 当前总资产 106565.657824
# self.stats 最大回撤 6.543150020572928
# self.stats 收益 0.0006193530865818975
# 2020-11-13T00:00:00
# CLOSE 100 close 219.48494799
# 2020-11-16T00:00:00
# getcash 当前可用资金 106065.454211
# getvalue 当前总资产 106065.454211
# 2020-11-13T00:00:00
# self.stats 当前可用资金 84078.482211
# self.stats 当前总资产 106026.97701
# self.stats 最大回撤 7.0155668671328035
# self.stats 收益 -0.005054919427135318
# 2020-11-17T00:00:00
# getcash 当前可用资金 106065.454211
# getvalue 当前总资产 106065.454211
# 2020-11-16T00:00:00
# self.stats 当前可用资金 106065.454211
# self.stats 当前总资产 106065.454211
# self.stats 最大回撤 6.9818228066642405
# self.stats 收益 0.00036290010415340745
# 2020-11-18T00:00:00
# getcash 当前可用资金 106065.454211
# getvalue 当前总资产 106065.454211
# 2020-11-17T00:00:00
# self.stats 当前可用资金 106065.454211
# self.stats 当前总资产 106065.454211
# self.stats 最大回撤 6.9818228066642405
# self.stats 收益 0.0
# 2020-11-19T00:00:00
# getcash 当前可用资金 106065.454211
# getvalue 当前总资产 106065.454211
# 2020-11-18T00:00:00
# self.stats 当前可用资金 106065.454211
# self.stats 当前总资产 106065.454211
# self.stats 最大回撤 6.9818228066642405
# self.stats 收益 0.0
# 2020-11-20T00:00:00
# getcash 当前可用资金 106065.454211
# getvalue 当前总资产 106065.454211
# 2020-11-19T00:00:00
# self.stats 当前可用资金 106065.454211
# self.stats 当前总资产 106065.454211
# self.stats 最大回撤 6.9818228066642405
# self.stats 收益 0.0
# 2020-11-23T00:00:00
# getcash 当前可用资金 106065.454211
# getvalue 当前总资产 106065.454211
# 2020-11-20T00:00:00
# self.stats 当前可用资金 106065.454211
# self.stats 当前总资产 106065.454211
# self.stats 最大回撤 6.9818228066642405
# self.stats 收益 0.0
# 2020-11-24T00:00:00
# getcash 当前可用资金 106065.454211
# getvalue 当前总资产 106065.454211
# 2020-11-23T00:00:00
# self.stats 当前可用资金 106065.454211
# self.stats 当前总资产 106065.454211
# self.stats 最大回撤 6.9818228066642405
# self.stats 收益 0.0
# 2020-11-25T00:00:00
# getcash 当前可用资金 106065.454211
# getvalue 当前总资产 106065.454211
# 2020-11-24T00:00:00
# self.stats 当前可用资金 106065.454211
# self.stats 当前总资产 106065.454211
# self.stats 最大回撤 6.9818228066642405
# self.stats 收益 0.0
# 2020-11-26T00:00:00
# getcash 当前可用资金 106065.454211
# getvalue 当前总资产 106065.454211
# 2020-11-25T00:00:00
# self.stats 当前可用资金 106065.454211
# self.stats 当前总资产 106065.454211
# self.stats 最大回撤 6.9818228066642405
# self.stats 收益 0.0
# 2020-11-27T00:00:00
# getcash 当前可用资金 106065.454211
# getvalue 当前总资产 106065.454211
# 2020-11-26T00:00:00
# self.stats 当前可用资金 106065.454211
# self.stats 当前总资产 106065.454211
# self.stats 最大回撤 6.9818228066642405
# self.stats 收益 0.0
# 2020-11-30T00:00:00
# getcash 当前可用资金 106065.454211
# getvalue 当前总资产 106065.454211
# 2020-11-27T00:00:00
# self.stats 当前可用资金 106065.454211
# self.stats 当前总资产 106065.454211
# self.stats 最大回撤 6.9818228066642405
# self.stats 收益 0.0
# 2020-12-01T00:00:00
# getcash 当前可用资金 106065.454211
# getvalue 当前总资产 106065.454211
# 2020-11-30T00:00:00
# self.stats 当前可用资金 106065.454211
# self.stats 当前总资产 106065.454211
# self.stats 最大回撤 6.9818228066642405
# self.stats 收益 0.0
# 2020-12-02T00:00:00
# getcash 当前可用资金 106065.454211
# getvalue 当前总资产 106065.454211
# 2020-12-01T00:00:00
# self.stats 当前可用资金 106065.454211
# self.stats 当前总资产 106065.454211
# self.stats 最大回撤 6.9818228066642405
# self.stats 收益 0.0
# 2020-12-03T00:00:00
# getcash 当前可用资金 106065.454211
# getvalue 当前总资产 106065.454211
# 2020-12-02T00:00:00
# self.stats 当前可用资金 106065.454211
# self.stats 当前总资产 106065.454211
# self.stats 最大回撤 6.9818228066642405
# self.stats 收益 0.0
# 2020-12-04T00:00:00
# getcash 当前可用资金 106065.454211
# getvalue 当前总资产 106065.454211
# 2020-12-03T00:00:00
# self.stats 当前可用资金 106065.454211
# self.stats 当前总资产 106065.454211
# self.stats 最大回撤 6.9818228066642405
# self.stats 收益 0.0
# 2020-12-07T00:00:00
# getcash 当前可用资金 106065.454211
# getvalue 当前总资产 106065.454211
# 2020-12-04T00:00:00
# self.stats 当前可用资金 106065.454211
# self.stats 当前总资产 106065.454211
# self.stats 最大回撤 6.9818228066642405
# self.stats 收益 0.0
# 2020-12-08T00:00:00
# getcash 当前可用资金 106065.454211
# getvalue 当前总资产 106065.454211
# 2020-12-07T00:00:00
# self.stats 当前可用资金 106065.454211
# self.stats 当前总资产 106065.454211
# self.stats 最大回撤 6.9818228066642405
# self.stats 收益 0.0
# 2020-12-09T00:00:00
# getcash 当前可用资金 106065.454211
# getvalue 当前总资产 106065.454211
# 2020-12-08T00:00:00
# self.stats 当前可用资金 106065.454211
# self.stats 当前总资产 106065.454211
# self.stats 最大回撤 6.9818228066642405
# self.stats 收益 0.0
# 2020-12-10T00:00:00
# getcash 当前可用资金 106065.454211
# getvalue 当前总资产 106065.454211
# 2020-12-09T00:00:00
# self.stats 当前可用资金 106065.454211
# self.stats 当前总资产 106065.454211
# self.stats 最大回撤 6.9818228066642405
# self.stats 收益 0.0
# 2020-12-10T00:00:00
# BUY 100 close 214.09813985
# 2020-12-11T00:00:00
# getcash 当前可用资金 84848.026231
# getvalue 当前总资产 105708.165916
# 2020-12-10T00:00:00
# self.stats 当前可用资金 106065.454211
# self.stats 当前总资产 106065.454211
# self.stats 最大回撤 6.9818228066642405
# self.stats 收益 0.0
# 2020-12-11T00:00:00
# CLOSE 100 close 208.60139685
# 2020-12-14T00:00:00
# getcash 当前可用资金 105834.591005
# getvalue 当前总资产 105834.591005
# 2020-12-11T00:00:00
# self.stats 当前可用资金 84848.026231
# self.stats 当前总资产 105708.165916
# self.stats 最大回撤 7.295160511015188
# self.stats 收益 -0.003368564229114912
# 2020-12-15T00:00:00
# getcash 当前可用资金 105834.591005
# getvalue 当前总资产 105834.591005
# 2020-12-14T00:00:00
# self.stats 当前可用资金 105834.591005
# self.stats 当前总资产 105834.591005
# self.stats 最大回撤 7.184287169475627
# self.stats 收益 0.0011959822394465025
# 2020-12-16T00:00:00
# getcash 当前可用资金 105834.591005
# getvalue 当前总资产 105834.591005
# 2020-12-15T00:00:00
# self.stats 最大回撤 7.8880918592485205
# self.stats 收益 0.003097266535521559
# 2021-01-14T00:00:00
# getcash 当前可用资金 84061.99198199999
# getvalue 当前总资产 104020.66581499999
# 2021-01-13T00:00:00
# self.stats 当前可用资金 84061.99198199999
# self.stats 当前总资产 104344.97365199999
# self.stats 最大回撤 8.49066436761572
# self.stats 收益 -0.006541743847564674
# 2021-01-15T00:00:00
# getcash 当前可用资金 84061.99198199999
# getvalue 当前总资产 103322.57945399999
# 2021-01-14T00:00:00
# self.stats 当前可用资金 84061.99198199999
# self.stats 当前总资产 104020.66581499999
# self.stats 最大回撤 8.775078591565038
# self.stats 收益 -0.003108035065317094
# 2021-01-15T00:00:00
# CLOSE 100 close 192.60587472
# 2021-01-18T00:00:00
# getcash 当前可用资金 103350.06316899999
# getvalue 当前总资产 103350.06316899999
# 2021-01-15T00:00:00
# self.stats 当前可用资金 84061.99198199999
# self.stats 当前总资产 103322.57945399999
# self.stats 最大回撤 9.387292260066108
# self.stats 收益 -0.006711035307556457
# 2021-01-19T00:00:00
# getcash 当前可用资金 103350.06316899999
# getvalue 当前总资产 103350.06316899999
# 2021-01-18T00:00:00
# self.stats 当前可用资金 103350.06316899999
# self.stats 当前总资产 103350.06316899999
# self.stats 最大回撤 9.363189359731422
# self.stats 收益 0.0002659991179587706
# 2021-01-20T00:00:00
# getcash 当前可用资金 103350.06316899999
# getvalue 当前总资产 103350.06316899999
# 2021-01-19T00:00:00
# self.stats 当前可用资金 103350.06316899999
# self.stats 当前总资产 103350.06316899999
# self.stats 最大回撤 9.363189359731422
# self.stats 收益 0.0
# 2021-01-21T00:00:00
# getcash 当前可用资金 103350.06316899999
# getvalue 当前总资产 103350.06316899999
# 2021-01-20T00:00:00
# self.stats 当前可用资金 103350.06316899999
# self.stats 当前总资产 103350.06316899999
# self.stats 最大回撤 9.363189359731422
# self.stats 收益 0.0
# 2021-01-22T00:00:00
# getcash 当前可用资金 103350.06316899999
# getvalue 当前总资产 103350.06316899999
# 2021-01-21T00:00:00
# self.stats 当前可用资金 103350.06316899999
# self.stats 当前总资产 103350.06316899999
# self.stats 最大回撤 9.363189359731422
# self.stats 收益 0.0
# 2021-01-22T00:00:00
# BUY 100 close 203.15962128
# 2021-01-25T00:00:00
# getcash 当前可用资金 83160.52612999998
# getvalue 当前总资产 103602.91334699998
# 2021-01-22T00:00:00
# self.stats 当前可用资金 103350.06316899999
# self.stats 当前总资产 103350.06316899999
# self.stats 最大回撤 9.363189359731422
# self.stats 收益 0.0
# 2021-01-26T00:00:00
# getcash 当前可用资金 83160.52612999998
# getvalue 当前总资产 103102.70973399997
# 2021-01-25T00:00:00
# self.stats 当前可用资金 83160.52612999998
# self.stats 当前总资产 103602.91334699998
# self.stats 最大回撤 9.1414426766523
# self.stats 收益 0.0024465411074450216
# 2021-01-27T00:00:00
# getcash 当前可用资金 83160.52612999998
# getvalue 当前总资产 103536.95243099998
# 2021-01-26T00:00:00
# self.stats 当前可用资金 83160.52612999998
# self.stats 当前总资产 103102.70973399997
# self.stats 最大回撤 9.580115462743626
# self.stats 收益 -0.004828084431609203
# 2021-01-28T00:00:00
# getcash 当前可用资金 83160.52612999998
# getvalue 当前总资产 105037.56326999998
# 2021-01-27T00:00:00
# self.stats 当前可用资金 83160.52612999998
# self.stats 当前总资产 103536.95243099998
# self.stats 最大回撤 9.199289637455548
# self.stats 收益 0.0042117486351263
# ---------stop----------
# 2021-01-28T00:00:00
# getcash 当前可用资金 83160.52612999998
# getvalue 当前总资产 105037.56326999998
# 2021-01-27T00:00:00
# self.stats 当前可用资金 83160.52612999998
# self.stats 当前总资产 105037.56326999998
# self.stats 最大回撤 7.883271279181587
# self.stats 收益 0.01449348086616764
# [[<Figure size 1500x1500 with 16 Axes>]]

# %%
rasult[0].analyzers._TimeReturn.get_analysis()
# Out:
# OrderedDict([(datetime.datetime(2019, 1, 2, 0, 0), 0.0),
#              (datetime.datetime(2019, 1, 3, 0, 0), 0.0),
#              (datetime.datetime(2019, 1, 4, 0, 0), 0.0),
#              (datetime.datetime(2019, 1, 7, 0, 0), 0.0),
#              (datetime.datetime(2019, 1, 8, 0, 0), 0.0),
#              (datetime.datetime(2019, 1, 9, 0, 0), 0.0),
#              (datetime.datetime(2019, 1, 10, 0, 0), 0.0),
#              (datetime.datetime(2019, 1, 11, 0, 0), 0.0),
#              (datetime.datetime(2019, 1, 14, 0, 0), 0.0),
#              (datetime.datetime(2019, 1, 15, 0, 0), 0.0),
#              (datetime.datetime(2019, 1, 16, 0, 0), 0.0),
#              (datetime.datetime(2019, 1, 17, 0, 0), 0.0),
#              (datetime.datetime(2019, 1, 18, 0, 0), 0.0),
#              (datetime.datetime(2019, 1, 21, 0, 0), 0.0),
#              (datetime.datetime(2019, 1, 22, 0, 0), 0.0),
#              (datetime.datetime(2019, 1, 23, 0, 0), 0.0),
#              (datetime.datetime(2019, 1, 24, 0, 0), 0.0),
#              (datetime.datetime(2019, 1, 25, 0, 0), 0.0),
#              (datetime.datetime(2019, 1, 28, 0, 0), 0.0),
#              (datetime.datetime(2019, 1, 29, 0, 0), 0.0),
#              (datetime.datetime(2019, 1, 30, 0, 0), 0.0),
#              (datetime.datetime(2019, 1, 31, 0, 0), 0.0),
#              (datetime.datetime(2019, 2, 1, 0, 0), 0.0),
#              (datetime.datetime(2019, 2, 11, 0, 0), 0.0),
#              (datetime.datetime(2019, 2, 12, 0, 0), 0.0),
#              (datetime.datetime(2019, 2, 13, 0, 0), 0.0),
#              (datetime.datetime(2019, 2, 14, 0, 0), 0.0),
#              (datetime.datetime(2019, 2, 15, 0, 0), 0.0),
#              (datetime.datetime(2019, 2, 18, 0, 0), 0.0),
#              (datetime.datetime(2019, 2, 19, 0, 0), 0.0),
#              (datetime.datetime(2019, 2, 20, 0, 0), 0.0),
#              (datetime.datetime(2019, 2, 21, 0, 0), 0.0),
#              (datetime.datetime(2019, 2, 22, 0, 0), 0.0),
#              (datetime.datetime(2019, 2, 25, 0, 0), 0.0),
#              (datetime.datetime(2019, 2, 26, 0, 0), 0.0),
#              (datetime.datetime(2019, 2, 27, 0, 0), 0.0),
#              (datetime.datetime(2019, 2, 28, 0, 0), 0.0),
#              (datetime.datetime(2019, 3, 1, 0, 0), 0.0),
#              (datetime.datetime(2019, 3, 4, 0, 0), 0.0),
#              (datetime.datetime(2019, 3, 5, 0, 0), 0.0),
#              (datetime.datetime(2019, 3, 6, 0, 0), 0.0),
#              (datetime.datetime(2019, 3, 7, 0, 0), 0.0),
#              (datetime.datetime(2019, 3, 8, 0, 0), 0.0),
#              (datetime.datetime(2019, 3, 11, 0, 0), 0.0),
#              (datetime.datetime(2019, 3, 12, 0, 0), 0.0),
#              (datetime.datetime(2019, 3, 13, 0, 0), 0.0),
#              (datetime.datetime(2019, 3, 14, 0, 0), 0.0),
#              (datetime.datetime(2019, 3, 15, 0, 0), 0.0),
#              (datetime.datetime(2019, 3, 18, 0, 0), 0.0),
#              (datetime.datetime(2019, 3, 19, 0, 0), 0.0),
#              (datetime.datetime(2019, 3, 20, 0, 0), 0.0),
#              (datetime.datetime(2019, 3, 21, 0, 0), 0.0),
#              (datetime.datetime(2019, 3, 22, 0, 0), 0.0),
#              (datetime.datetime(2019, 3, 25, 0, 0), 0.0),
#              (datetime.datetime(2019, 3, 26, 0, 0), 0.0),
#              (datetime.datetime(2019, 3, 27, 0, 0), 0.0),
#              (datetime.datetime(2019, 3, 28, 0, 0), 0.0),
#              (datetime.datetime(2019, 3, 29, 0, 0), 0.0),
#              (datetime.datetime(2019, 4, 1, 0, 0), 0.0),
#              (datetime.datetime(2019, 4, 2, 0, 0), 0.0),
#              (datetime.datetime(2019, 4, 3, 0, 0), 0.0),
#              (datetime.datetime(2019, 4, 4, 0, 0), 0.0),
#              (datetime.datetime(2019, 4, 8, 0, 0), -0.0034680332799998936),
#              (datetime.datetime(2019, 4, 9, 0, 0), -0.0005437659985796373),
#              (datetime.datetime(2019, 4, 10, 0, 0), 0.0),
#              (datetime.datetime(2019, 4, 11, 0, 0), 0.0),
#              (datetime.datetime(2019, 4, 12, 0, 0), 0.0),
#              (datetime.datetime(2019, 4, 15, 0, 0), 0.0),
#              (datetime.datetime(2019, 4, 16, 0, 0), 0.0),
#              (datetime.datetime(2019, 4, 17, 0, 0), 0.0),
#              (datetime.datetime(2019, 4, 18, 0, 0), 0.0),
#              (datetime.datetime(2019, 4, 19, 0, 0), 0.0),
#              (datetime.datetime(2019, 4, 22, 0, 0), 0.0),
#              (datetime.datetime(2019, 4, 23, 0, 0), 0.0),
#              (datetime.datetime(2019, 4, 24, 0, 0), 0.0),
#              (datetime.datetime(2019, 4, 25, 0, 0), 0.0),
#              (datetime.datetime(2019, 4, 26, 0, 0), 0.0),
#              (datetime.datetime(2019, 4, 29, 0, 0), 0.0),
#              (datetime.datetime(2019, 4, 30, 0, 0), 0.0),
#              (datetime.datetime(2019, 5, 6, 0, 0), 0.0),
#              (datetime.datetime(2019, 5, 7, 0, 0), 0.0),
#              (datetime.datetime(2019, 5, 8, 0, 0), 0.0),
#              (datetime.datetime(2019, 5, 9, 0, 0), 0.0),
#              (datetime.datetime(2019, 5, 10, 0, 0), 0.0),
#              (datetime.datetime(2019, 5, 13, 0, 0), 0.0),
#              (datetime.datetime(2019, 5, 14, 0, 0), 0.0),
#              (datetime.datetime(2019, 5, 15, 0, 0), 0.0),
#              (datetime.datetime(2019, 5, 16, 0, 0), 0.0),
#              (datetime.datetime(2019, 5, 17, 0, 0), 0.0),
#              (datetime.datetime(2019, 5, 20, 0, 0), 0.0),
#              (datetime.datetime(2019, 5, 21, 0, 0), 0.0),
#              (datetime.datetime(2019, 5, 22, 0, 0), 0.0),
#              (datetime.datetime(2019, 5, 23, 0, 0), 0.0),
#              (datetime.datetime(2019, 5, 24, 0, 0), 0.0),
#              (datetime.datetime(2019, 5, 27, 0, 0), 0.0),
#              (datetime.datetime(2019, 5, 28, 0, 0), 0.0),
#              (datetime.datetime(2019, 5, 29, 0, 0), 0.0),
#              (datetime.datetime(2019, 5, 30, 0, 0), 0.0),
#              (datetime.datetime(2019, 5, 31, 0, 0), 0.0),
#              (datetime.datetime(2019, 6, 3, 0, 0), 0.0),
#              (datetime.datetime(2019, 6, 4, 0, 0), 0.0),
#              (datetime.datetime(2019, 6, 5, 0, 0), 0.0),
#              (datetime.datetime(2019, 6, 6, 0, 0), 0.0),
#              (datetime.datetime(2019, 6, 10, 0, 0), 0.0012513422340925118),
#              (datetime.datetime(2019, 6, 11, 0, 0), 0.002716909421044411),
#              (datetime.datetime(2019, 6, 12, 0, 0), -0.001408964869016538),
#              (datetime.datetime(2019, 6, 13, 0, 0), -0.0002713370869262821),
#              (datetime.datetime(2019, 6, 14, 0, 0), -0.0013027715074721558),
#              (datetime.datetime(2019, 6, 17, 0, 0), 0.0017392945800513981),
#              (datetime.datetime(2019, 6, 18, 0, 0), -0.0003255515037935419),
#              (datetime.datetime(2019, 6, 19, 0, 0), 0.001085525073632132),
#              (datetime.datetime(2019, 6, 20, 0, 0), 0.0037952179534637143),
#              (datetime.datetime(2019, 6, 21, 0, 0), -0.0001620372313958507),
#              (datetime.datetime(2019, 8, 23, 0, 0), -0.00026579440670038146),
#              (datetime.datetime(2019, 8, 26, 0, 0), -0.0019674015339061768),
#              (datetime.datetime(2019, 8, 27, 0, 0), -0.0006393339998507219),
#              (datetime.datetime(2019, 8, 28, 0, 0), 0.0012794860186156054),
#              (datetime.datetime(2019, 8, 29, 0, 0), -0.0022362392956640775),
#              (datetime.datetime(2019, 8, 30, 0, 0), -0.0019210725169931386),
#              (datetime.datetime(2019, 9, 2, 0, 0), 0.0005881242094476491),
#              (datetime.datetime(2019, 9, 3, 0, 0), 0.0017633355680062301),
#              (datetime.datetime(2019, 9, 4, 0, 0), -0.00714760746386045),
#              (datetime.datetime(2019, 9, 5, 0, 0), -0.0006984166124952562),
#              (datetime.datetime(2019, 9, 6, 0, 0), 0.00043009522410808465),
#              (datetime.datetime(2019, 9, 9, 0, 0), 0.0),
#              (datetime.datetime(2019, 9, 10, 0, 0), 0.0),
#              (datetime.datetime(2019, 9, 11, 0, 0), 0.0),
#              (datetime.datetime(2019, 9, 12, 0, 0), 0.0),
#              (datetime.datetime(2019, 9, 16, 0, 0), 0.0),
#              (datetime.datetime(2019, 9, 17, 0, 0), 0.0),
#              (datetime.datetime(2019, 9, 18, 0, 0), 0.0),
#              (datetime.datetime(2019, 9, 19, 0, 0), 0.0),
#              (datetime.datetime(2019, 9, 20, 0, 0), 0.0),
#              (datetime.datetime(2019, 9, 23, 0, 0), 0.0),
#              (datetime.datetime(2019, 9, 24, 0, 0), 0.0),
#              (datetime.datetime(2019, 9, 25, 0, 0), 0.0019883352380101194),
#              (datetime.datetime(2019, 9, 26, 0, 0), 0.00021452860607884539),
#              (datetime.datetime(2019, 9, 27, 0, 0), -0.0023056878793416002),
#              (datetime.datetime(2019, 9, 30, 0, 0), -0.0002687228327623581),
#              (datetime.datetime(2019, 10, 8, 0, 0), 0.0020428424874137097),
#              (datetime.datetime(2019, 10, 9, 0, 0), -0.0015558330501154183),
#              (datetime.datetime(2019, 10, 10, 0, 0), 0.014024316946850579),
#              (datetime.datetime(2019, 10, 11, 0, 0), -0.0027554731574470637),
#              (datetime.datetime(2019, 10, 14, 0, 0), -0.0012221345323849553),
#              (datetime.datetime(2019, 10, 15, 0, 0), 0.0003192078189990788),
#              (datetime.datetime(2019, 10, 16, 0, 0), 0.0001595529789411021),
#              (datetime.datetime(2019, 10, 17, 0, 0), -0.0019143303101896159),
#              (datetime.datetime(2019, 10, 18, 0, 0), 0.00010655566664174998),
#              (datetime.datetime(2019, 10, 21, 0, 0), 0.0010654431374141904),
#              (datetime.datetime(2019, 10, 22, 0, 0), 0.003139712070692635),
#              (datetime.datetime(2019, 10, 23, 0, 0), -0.0060475746629163885),
#              (datetime.datetime(2019, 10, 24, 0, 0), -0.0027753268248861263),
#              (datetime.datetime(2019, 10, 25, 0, 0), -0.010115318890927316),
#              (datetime.datetime(2019, 10, 28, 0, 0), -0.00027033555924982355),
#              (datetime.datetime(2019, 10, 29, 0, 0), -0.00021632692826101252),
#              (datetime.datetime(2019, 10, 30, 0, 0), 0.0),
#              (datetime.datetime(2019, 10, 31, 0, 0), 0.0),
#              (datetime.datetime(2019, 11,
 0, 0), 0.0),
#              (datetime.datetime(2020, 12, 30, 0, 0), 0.0),
#              (datetime.datetime(2020, 12, 31, 0, 0), 0.0),
#              (datetime.datetime(2021, 1, 4, 0, 0), 0.0),
#              (datetime.datetime(2021, 1, 5, 0, 0), 0.0),
#              (datetime.datetime(2021, 1, 6, 0, 0), 0.0),
#              (datetime.datetime(2021, 1, 7, 0, 0), 0.0),
#              (datetime.datetime(2021, 1, 8, 0, 0), 0.0),
#              (datetime.datetime(2021, 1, 11, 0, 0), -0.0005246849908911999),
#              (datetime.datetime(2021, 1, 12, 0, 0), 0.003097266535521559),
#              (datetime.datetime(2021, 1, 13, 0, 0), -0.006541743847564674),
#              (datetime.datetime(2021, 1, 14, 0, 0), -0.003108035065317094),
#              (datetime.datetime(2021, 1, 15, 0, 0), -0.006711035307556457),
#              (datetime.datetime(2021, 1, 18, 0, 0), 0.0002659991179587706),
#              (datetime.datetime(2021, 1, 19, 0, 0), 0.0),
#              (datetime.datetime(2021, 1, 20, 0, 0), 0.0),
#              (datetime.datetime(2021, 1, 21, 0, 0), 0.0),
#              (datetime.datetime(2021, 1, 22, 0, 0), 0.0),
#              (datetime.datetime(2021, 1, 25, 0, 0), 0.0024465411074450216),
#              (datetime.datetime(2021, 1, 26, 0, 0), -0.004828084431609203),
#              (datetime.datetime(2021, 1, 27, 0, 0), 0.0042117486351263),
#              (datetime.datetime(2021, 1, 28, 0, 0), 0.01449348086616764)])

# %%
rasult[0].analyzers._TimeDrawDown.get_analysis()
# Out:
# OrderedDict([('maxdrawdown', 9.580115462743626), ('maxdrawdownperiod', 150)])

# %% [markdown]
# # 四、将 observers 中的数据读到本地

# %%
import backtrader as bt
import csv

class TestStrategy(bt.Strategy):
    params = (
        ('period1', 5),
        ('period2', 20),
    )

    def __init__(self):
        sma1 = bt.indicators.SMA(period=self.p.period1)  # 短期均线
        sma2 = bt.indicators.SMA(period=self.p.period2)  # 长期均线
        # 短期均线上穿长期均线，取值为 1；短期均线下穿长期均线，取值为 -1；相等，取值为 0
        self.crossover = bt.indicators.CrossOver(sma1, sma2)  
        self.order = None
        
    def start(self):
        self.mystats = csv.writer(open("mystats.csv", "w"))
        self.mystats.writerow(['datetime',
                               'drawdown', 'maxdrawdown', 
                               'timereturn',
                               'value', 'cash'])
        
    def next(self): 
        self.mystats.writerow([self.data.datetime.date(-1).strftime('%Y-%m-%d'),
                               '%.4f' % self.stats.drawdown.drawdown[0],
                               '%.4f' % self.stats.drawdown.maxdrawdown[0],
                               '%.4f' % self.stats.timereturn.line[0],
                               '%.4f' % self.stats.broker.value[0],
                               '%.4f' % self.stats.broker.cash[0]])
        
        if self.position:
            if self.crossover < 0.0: 
                self.order = self.close()
                print(bt.num2date(self.data.datetime[0]).isoformat())
                print('CLOSE {} close {}'.format(self.position.size, self.data.close[0]))
        # 上穿买入
        else:
            if self.crossover > 0.0:
                self.order = self.buy(size=100)
                print(bt.num2date(self.data.datetime[0]).isoformat())
                print('BUY {} close {}'.format(100, self.data.close[0]))
                
    def stop(self):  
        self.mystats.writerow([self.data.datetime.date(0).strftime('%Y-%m-%d'),
                               '%.4f' % self.stats.drawdown.drawdown[0],
                               '%.4f' % self.stats.drawdown.maxdrawdown[0],
                               '%.4f' % self.stats.timereturn.line[0],
                               '%.4f' % self.stats.broker.value[0],
                               '%.4f' % self.stats.broker.cash[0]])

        
cerebro = bt.Cerebro()
cerebro.broker.set_cash(100000)
st_date = datetime.datetime(2019,1,2)
ed_date = datetime.datetime(2021,1,28)
datafeed1 = bt.feeds.PandasData(dataname=data1, fromdate=st_date, todate=ed_date)
cerebro.adddata(datafeed1, name='600315.SH')
cerebro.addanalyzer(bt.analyzers.TimeDrawDown, _name='_TimeDrawDown')
cerebro.addanalyzer(bt.analyzers.TimeReturn, _name='_TimeReturn')
cerebro.addstrategy(TestStrategy)
cerebro.addobserver(bt.observers.DrawDown)
cerebro.addobserver(bt.observers.TimeReturn)
cerebro.addobserver(bt.observers.Benchmark, data=datafeed1)
rasult = cerebro.run()
cerebro.plot(iplot=False)
# Out:
# 2019-04-04T00:00:00
# BUY 100 close 171.01739112
# 2019-04-08T00:00:00
# CLOSE 100 close 167.87448596
# 2019-06-06T00:00:00
# BUY 100 close 154.59842106
# 2019-07-19T00:00:00
# CLOSE 100 close 166.51978546
# 2019-08-12T00:00:00
# BUY 100 close 173.21505054
# 2019-09-05T00:00:00
# CLOSE 100 close 180.31626674
# 2019-09-24T00:00:00
# BUY 100 close 188.34610352
# 2019-10-28T00:00:00
# CLOSE 100 close 181.57263576
# 2019-12-17T00:00:00
# BUY 100 close 167.58870232
# 2019-12-26T00:00:00
# CLOSE 100 close 163.92884474
# 2019-12-31T00:00:00
# BUY 100 close 169.00894556
# 2020-01-20T00:00:00
# CLOSE 100 close 161.03373352
# 2020-04-21T00:00:00
# BUY 100 close 138.03671798
# 2020-07-15T00:00:00
# CLOSE 100 close 255.86228216
# 2020-08-03T00:00:00
# BUY 100 close 254.33278944
# 2020-08-10T00:00:00
# CLOSE 100 close 236.36124998
# 2020-09-03T00:00:00
# BUY 100 close 236.359949
# 2020-09-09T00:00:00
# CLOSE 100 close 213.32859583
# 2020-10-12T00:00:00
# BUY 100 close 228.99431338
# 2020-10-27T00:00:00
# CLOSE 100 close 224.2671144
# 2020-10-29T00:00:00
# BUY 100 close 235.70033984
# 2020-11-13T00:00:00
# CLOSE 100 close 219.48494799
# 2020-12-10T00:00:00
# BUY 100 close 214.09813985
# 2020-12-11T00:00:00
# CLOSE 100 close 208.60139685
# 2020-12-16T00:00:00
# BUY 100 close 219.26507827
# 2020-12-22T00:00:00
# CLOSE 100 close 206.51263451
# 2021-01-08T00:00:00
# BUY 100 close 205.24838362
# 2021-01-15T00:00:00
# CLOSE 100 close 192.60587472
# 2021-01-22T00:00:00
# BUY 100 close 203.15962128
# [[<Figure size 1500x1500 with 24 Axes>]]

# %% [markdown]
# # 五、部分修改样式

# %%
import backtrader as bt
plt.style.use('seaborn-v0_8')
plt.rcParams['figure.figsize'] = 20, 10

class my_Trades(bt.observers.Trades):
    plotlines = dict(
    pnlplus=dict(_name='Positive',
                 marker='^', color='#ed665d',
                 markersize=8.0, fillstyle='full'),
    pnlminus=dict(_name='Negative',
                  marker='v', color='#729ece',
                  markersize=8.0, fillstyle='full'))


class my_BuySell(bt.observers.BuySell):
    
    params = (('barplot', True), ('bardist', 0.02))
    
    plotlines = dict(
    buy=dict(marker=r'$\Uparrow$', markersize=10.0, color='#d62728' ),
    sell=dict(marker=r'$\Downarrow$', markersize=10.0, color='#2ca02c'))
    
    

class TestStrategy(bt.Strategy):
    params = (
        ('period1', 5),
        ('period2', 20),
    )

    def __init__(self):
        sma1 = bt.indicators.SMA(period=self.p.period1)  # 短期均线
        sma2 = bt.indicators.SMA(period=self.p.period2)  # 长期均线
        
        # 短期均线上穿长期均线，取值为 1；短期均线下穿长期均线，取值为 -1；相等，取值为 0
        self.crossover = bt.indicators.CrossOver(sma1, sma2, plot=True)  
        self.order = None
        
    def next(self):
        # 下穿卖出
        if self.position:
            if self.crossover < 0.0: 
                self.order = self.close()
                print('CLOSE {} close {}'.format(self.position.size, self.data.close[0]))
        # 上穿买入
        else:
            if self.crossover > 0.0:
                self.order = self.buy(size=100)
                print('BUY {} close {}'.format(100, self.data.close[0]))

        
cerebro1 = bt.Cerebro(stdstats=False)
cerebro1.broker.set_cash(100000)
st_date = datetime.datetime(2019,1,2)
ed_date = datetime.datetime(2021,1,28)
datafeed1 = bt.feeds.PandasData(dataname=data1, fromdate=st_date, todate=ed_date)
cerebro1.adddata(datafeed1, name='600315.SH')
cerebro1.addstrategy(TestStrategy)
cerebro1.addobserver(bt.observers.DrawDown)
cerebro1.addobserver(bt.observers.Benchmark, data=datafeed1)
cerebro1.addobserver(bt.observers.Broker)
cerebro1.addobserver(my_Trades)
cerebro1.addobserver(my_BuySell)
rasult = cerebro1.run()
colors = ['#729ece', '#ff9e4a', '#67bf5c', '#ed665d', '#ad8bc9', '#a8786e', '#ed97ca', '#a2a2a2', '#cdcc5d', '#6dccda']
tab10_index = [3, 0, 2, 1, 2, 4, 5, 6, 7, 8, 9]
cerebro1.plot(iplot=False,  
              style='line', 
              lcolors=colors ,
              plotdist=0.1, 
              bartrans=0.2, 
              volup='#ff9896', 
              voldown='#98df8a', 
              loc='#5f5a41',
              grid=False)
# Out:
# BUY 100 close 171.01739112
# CLOSE 100 close 167.87448596
# BUY 100 close 154.59842106
# CLOSE 100 close 166.51978546
# BUY 100 close 173.21505054
# CLOSE 100 close 180.31626674
# BUY 100 close 188.34610352
# CLOSE 100 close 181.57263576
# BUY 100 close 167.58870232
# CLOSE 100 close 163.92884474
# BUY 100 close 169.00894556
# CLOSE 100 close 161.03373352
# BUY 100 close 138.03671798
# CLOSE 100 close 255.86228216
# BUY 100 close 254.33278944
# CLOSE 100 close 236.36124998
# BUY 100 close 236.359949
# CLOSE 100 close 213.32859583
# BUY 100 close 228.99431338
# CLOSE 100 close 224.2671144
# BUY 100 close 235.70033984
# CLOSE 100 close 219.48494799
# BUY 100 close 214.09813985
# CLOSE 100 close 208.60139685
# BUY 100 close 219.26507827
# CLOSE 100 close 206.51263451
# BUY 100 close 205.24838362
# CLOSE 100 close 192.60587472
# BUY 100 close 203.15962128
# [[<Figure size 1500x1500 with 31 Axes>]]

# %% [markdown]
# ### 将上图转换为蜡烛图，由于蜡烛图排列较紧密，通过设置 numfigs=2，将其分为 2 部分绘制

# %%
import backtrader as bt
plt.style.use('seaborn-v0_8')
plt.rcParams['figure.figsize'] = 15, 10


class my_Trades(bt.observers.Trades):
    plotlines = dict(
    pnlplus=dict(_name='Positive',
                 marker='^', color='#ed665d',
                 markersize=8.0, fillstyle='full'),
    pnlminus=dict(_name='Negative',
                  marker='v', color='#729ece',
                  markersize=8.0, fillstyle='full'))


class my_BuySell(bt.observers.BuySell):
    
    params = (('barplot', True), ('bardist', 0.02))
    
    plotlines = dict(
    buy=dict(marker=r'$\Uparrow$', markersize=10.0, color='#d62728' ),
    sell=dict(marker=r'$\Downarrow$', markersize=10.0, color='#2ca02c'))
    

class TestStrategy(bt.Strategy):
    params = (
        ('period1', 5),
        ('period2', 20),
    )

    def __init__(self):
        sma1 = bt.indicators.SMA(period=self.p.period1)  # 短期均线
        sma2 = bt.indicators.SMA(period=self.p.period2)  # 长期均线
        # 短期均线上穿长期均线，取值为 1；短期均线下穿长期均线，取值为 -1；相等，取值为 0
        self.crossover = bt.indicators.CrossOver(sma1, sma2, plot=True)  
        self.order = None
        
    def next(self):
        # 下穿卖出
        if self.position:
            if self.crossover < 0.0: 
                self.order = self.close()
                print('CLOSE {} close {}'.format(self.position.size, self.data.close[0]))
        # 上穿买入
        else:
            if self.crossover > 0.0:
                self.order = self.buy(size=100)
                print('BUY {} close {}'.format(100, self.data.close[0]))

        
cerebro1 = bt.Cerebro(stdstats=False)
cerebro1.broker.set_cash(100000)
st_date = datetime.datetime(2019,1,2)
ed_date = datetime.datetime(2021,1,28)
datafeed1 = bt.feeds.PandasData(dataname=data1, fromdate=st_date, todate=ed_date)
cerebro1.adddata(datafeed1, name='600315.SH')
cerebro1.addstrategy(TestStrategy)
cerebro1.addobserver(bt.observers.DrawDown)
cerebro1.addobserver(bt.observers.Benchmark, data=datafeed1)
cerebro1.addobserver(bt.observers.Broker)
cerebro1.addobserver(my_Trades)
cerebro1.addobserver(my_BuySell)
rasult = cerebro1.run()
colors = ['#729ece', '#ff9e4a', '#67bf5c', '#ed665d', '#ad8bc9', '#a8786e', '#ed97ca', '#a2a2a2', '#cdcc5d', '#6dccda']
tab10_index = [3, 0, 2, 1, 2, 4, 5, 6, 7, 8, 9]
cerebro1.plot(iplot=False,  style='candel', 
              lcolors=colors , 
              plotdist=0.1, 
              bartrans=0.2, 
              barup = '#ff9896', bardown='#98df8a',
              volup='#ff9896', voldown='#98df8a',  numfigs=2,
              grid=False)
# Out:
# BUY 100 close 171.01739112
# CLOSE 100 close 167.87448596
# BUY 100 close 154.59842106
# CLOSE 100 close 166.51978546
# BUY 100 close 173.21505054
# CLOSE 100 close 180.31626674
# BUY 100 close 188.34610352
# CLOSE 100 close 181.57263576
# BUY 100 close 167.58870232
# CLOSE 100 close 163.92884474
# BUY 100 close 169.00894556
# CLOSE 100 close 161.03373352
# BUY 100 close 138.03671798
# CLOSE 100 close 255.86228216
# BUY 100 close 254.33278944
# CLOSE 100 close 236.36124998
# BUY 100 close 236.359949
# CLOSE 100 close 213.32859583
# BUY 100 close 228.99431338
# CLOSE 100 close 224.2671144
# BUY 100 close 235.70033984
# CLOSE 100 close 219.48494799
# BUY 100 close 214.09813985
# CLOSE 100 close 208.60139685
# BUY 100 close 219.26507827
# CLOSE 100 close 206.51263451
# BUY 100 close 205.24838362
# CLOSE 100 close 192.60587472
# BUY 100 close 203.15962128
# [[<Figure size 1500x1500 with 38 Axes>, <Figure size 1500x1000 with 7 Axes>]]
# 在当前单元格或上一个单元格中执行代码时 Kernel 崩溃。
#
# 请查看单元格中的代码，以确定故障的可能原因。
#
# 单击<a href='https://aka.ms/vscodeJupyterKernelCrash'>此处</a>了解详细信息。
#
# 有关更多详细信息，请查看 Jupyter <a href='command:jupyter.viewOutput'>log</a>。

# %% [markdown]
# # 六、基于净值曲线进行可视化

# %%
class TestStrategy(bt.Strategy):
    params = (
        ('period1', 5),
        ('period2', 20),
    )

    def __init__(self):
        sma1 = bt.indicators.SMA(period=self.p.period1)  # 短期均线
        sma2 = bt.indicators.SMA(period=self.p.period2)  # 长期均线
        # 短期均线上穿长期均线，取值为 1；短期均线下穿长期均线，取值为 -1；相等，取值为 0
        self.crossover = bt.indicators.CrossOver(sma1, sma2, plot=True)  
        self.order = None
        
    def next(self):
        # 下穿卖出
        if self.position:
            if self.crossover < 0.0: 
                self.order = self.close()
                print('CLOSE {} close {}'.format(self.position.size, self.data.close[0]))
        # 上穿买入
        else:
            if self.crossover > 0.0:
                self.order = self.buy(size=100)
                print('BUY {} close {}'.format(100, self.data.close[0]))

        
cerebro1 = bt.Cerebro(stdstats=False)
cerebro1.broker.set_cash(100000)
st_date = datetime.datetime(2019,1,2)
ed_date = datetime.datetime(2021,1,28)
datafeed1 = bt.feeds.PandasData(dataname=data1, fromdate=st_date, todate=ed_date)
cerebro1.adddata(datafeed1, name='600315.SH')
cerebro1.addstrategy(TestStrategy)
cerebro1.addanalyzer(bt.analyzers.TimeReturn, _name='_TimeReturn')
result = cerebro1.run()

# %%
# 提取收益序列
pnl = pd.Series(result[0].analyzers._TimeReturn.get_analysis())
# 计算累计收益
cumulative = (pnl + 1).cumprod()
# 计算回撤序列
max_return = cumulative.cummax()
drawdown = (cumulative - max_return) / max_return
# 计算收益评价指标
import pyfolio as pf
# 按年统计收益指标
perf_stats_year = (pnl).groupby(pnl.index.to_period('y')).apply(lambda data: pf.timeseries.perf_stats(data)).unstack()
# 统计所有时间段的收益指标
perf_stats_all = pf.timeseries.perf_stats((pnl)).to_frame(name='all')
perf_stats = pd.concat([perf_stats_year, perf_stats_all.T], axis=0)
perf_stats_ = round(perf_stats,4).reset_index()


# 绘制图形
import matplotlib.pyplot as plt
plt.rcParams['axes.unicode_minus'] = False  # 用来正常显示负号
import matplotlib.ticker as ticker  # 导入设置坐标轴的模块
plt.style.use('seaborn')  # plt.style.use('dark_background')


fig, (ax0, ax1) = plt.subplots(2,1, gridspec_kw = {'height_ratios':[1.5, 4]}, figsize=(20,8))
cols_names = ['date', 'Annual\nreturn', 'Cumulative\nreturns', 'Annual\nvolatility',
       'Sharpe\nratio', 'Calmar\nratio', 'Stability', 'Max\ndrawdown',
       'Omega\nratio', 'Sortino\nratio', 'Skew', 'Kurtosis', 'Tail\nratio',
       'Daily value\nat risk']

# 绘制表格
ax0.set_axis_off()  # 除去坐标轴
table = ax0.table(cellText = perf_stats_.values, 
                bbox=(0,0,1,1),  # 设置表格位置， (x0, y0, width, height)
                rowLoc = 'right',  # 行标题居中
                cellLoc='right' ,
                colLabels = cols_names, # 设置列标题
                colLoc = 'right',  # 列标题居中
                edges = 'open' # 不显示表格边框
                )
table.set_fontsize(13)

# 绘制累计收益曲线
ax2 = ax1.twinx()
ax1.yaxis.set_ticks_position('right') # 将回撤曲线的 y 轴移至右侧
ax2.yaxis.set_ticks_position('left') # 将累计收益曲线的 y 轴移至左侧
# 绘制回撤曲线
drawdown.plot.area(ax=ax1, label='drawdown (right)', rot=0, alpha=0.3, fontsize=13, grid=False)
# 绘制累计收益曲线
(cumulative).plot(ax=ax2, color='#F1C40F' , lw=3.0, label='cumret (left)', rot=0, fontsize=13, grid=False)
# 不然 x 轴留有空白
ax2.set_xbound(lower=cumulative.index.min(), upper=cumulative.index.max())
# 主轴定位器：每 5 个月显示一个日期：根据具体天数来做排版
ax2.xaxis.set_major_locator(ticker.MultipleLocator(100)) 
# 同时绘制双轴的图例
h1,l1 = ax1.get_legend_handles_labels()
h2,l2 = ax2.get_legend_handles_labels()
plt.legend(h1+h2,l1+l2, fontsize=12, loc='upper left', ncol=1)

fig.tight_layout() # 规整排版
plt.show()

# %%
# 提取收益序列
pnl = pd.Series(result[0].analyzers._TimeReturn.get_analysis())
# 计算累计收益
cumulative = (pnl + 1).cumprod()
# 计算回撤序列
max_return = cumulative.cummax()
drawdown = (cumulative - max_return) / max_return
# 计算收益评价指标
import pyfolio as pf
# 按年统计收益指标
perf_stats_year = (pnl).groupby(pnl.index.to_period('y')).apply(lambda data: pf.timeseries.perf_stats(data)).unstack()
# 统计所有时间段的收益指标
perf_stats_all = pf.timeseries.perf_stats((pnl)).to_frame(name='all')
perf_stats = pd.concat([perf_stats_year, perf_stats_all.T], axis=0)
perf_stats_ = round(perf_stats,4).reset_index()


# 绘制图形
plt.rcParams['axes.unicode_minus'] = False  # 用来正常显示负号
import matplotlib.ticker as ticker  # 导入设置坐标轴的模块
plt.style.use('dark_background')  # plt.style.use('seaborn')


fig, (ax0, ax1) = plt.subplots(2,1, gridspec_kw = {'height_ratios':[1.5, 4]}, figsize=(20,8) )
cols_names = ['date', 'Annual\nreturn', 'Cumulative\nreturns', 'Annual\nvolatility',
       'Sharpe\nratio', 'Calmar\nratio', 'Stability', 'Max\ndrawdown',
       'Omega\nratio', 'Sortino\nratio', 'Skew', 'Kurtosis', 'Tail\nratio',
       'Daily value\nat risk']

# 绘制表格
ax0.set_axis_off()  # 除去坐标轴
table = ax0.table(cellText = perf_stats_.values, 
                bbox=(0,0,1,1),  # 设置表格位置， (x0, y0, width, height)
                rowLoc = 'right',  # 行标题居中
                cellLoc='right' ,
                colLabels = cols_names, # 设置列标题
                colLoc = 'right',  # 列标题居中
                edges = 'open' # 不显示表格边框
                )
table.set_fontsize(13)

# 绘制累计收益曲线
ax2 = ax1.twinx()
ax1.yaxis.set_ticks_position('right') # 将回撤曲线的 y 轴移至右侧
ax2.yaxis.set_ticks_position('left') # 将累计收益曲线的 y 轴移至左侧
# 绘制回撤曲线
drawdown.plot.area(ax=ax1, label='drawdown (right)', rot=0, alpha=0.3, fontsize=13, grid=False)
# 绘制累计收益曲线
(cumulative).plot(ax=ax2, color='#F1C40F' , lw=3.0, label='cumret (left)', rot=0, fontsize=13, grid=False)
# 不然 x 轴留有空白
ax2.set_xbound(lower=cumulative.index.min(), upper=cumulative.index.max())
# 主轴定位器：每 5 个月显示一个日期：根据具体天数来做排版
ax2.xaxis.set_major_locator(ticker.MultipleLocator(100)) 
# 同时绘制双轴的图例
h1,l1 = ax1.get_legend_handles_labels()
h2,l2 = ax2.get_legend_handles_labels()
plt.legend(h1+h2,l1+l2, fontsize=12, loc='upper left', ncol=1)

fig.tight_layout() # 规整排版
plt.show()
